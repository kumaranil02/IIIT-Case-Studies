# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
# Write your code for importing the csv file here
movies = pd.read_csv('Movie+Assignment+Data.csv')
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#       actor_1_name                                        movie_title  \
# 0      CCH Pounder                                            Avatar
# 1      Johnny Depp          Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                           Spectre
# 3        Tom Hardy                             The Dark Knight Rises
# 4      Doug Walker  Star Wars: Episode VII - The Force Awakens    ...
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 4                8                        143                   NaN
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 4                   0.0                                                NaN
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 4  http://www.imdb.com/title/tt5289954/?ref_=fn_t...                   NaN
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
# 2  English      UK          PG-13  245000000.0      2015.0
# 3  English     USA          PG-13  250000000.0      2012.0
# 4      NaN     NaN            NaN          NaN         NaN
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 4                    12.0         7.1           NaN                     0

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
# To check the dimentions of the data set
movies.shape
# Out:
# (5043, 28)

# %%
#glimpse of 5 reocrds of the dataset 
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#       actor_1_name                                        movie_title  \
# 0      CCH Pounder                                            Avatar
# 1      Johnny Depp          Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                           Spectre
# 3        Tom Hardy                             The Dark Knight Rises
# 4      Doug Walker  Star Wars: Episode VII - The Force Awakens    ...
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 4                8                        143                   NaN
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 4                   0.0                                                NaN
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 4  http://www.imdb.com/title/tt5289954/?ref_=fn_t...                   NaN
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
# 2  English      UK          PG-13  245000000.0      2015.0
# 3  English     USA          PG-13  250000000.0      2012.0
# 4      NaN     NaN            NaN          NaN         NaN
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 4                    12.0         7.1           NaN                     0

# %%
#Inspection of column names of dataset
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#data type of each column
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
round((movies.isnull().sum()*100)/len(movies),2)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# movie_facebook_likes          0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
print(movies.shape)
movies=movies.drop(['color','director_facebook_likes',
'actor_1_facebook_likes',
'actor_2_facebook_likes',
'actor_3_facebook_likes',
'actor_2_name',
'cast_total_facebook_likes',
'actor_3_name',
'duration',
'facenumber_in_poster',
'content_rating',
'country',
'movie_imdb_link',
'aspect_ratio',
'plot_keywords'],axis = 1)
print(movies.shape)
movies
# Out:
# (5043, 28)
# (5043, 13)
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# 3                     Action|Thriller        Tom Hardy
# 4                         Documentary      Doug Walker
# ...                               ...              ...
# 5038                     Comedy|Drama      Eric Mabius
# 5039     Crime|Drama|Mystery|Thriller      Natalie Zea
# 5040            Drama|Horror|Thriller      Eva Boehnke
# 5041             Comedy|Drama|Romance        Alan Ruck
# 5042                      Documentary      John August
#
#                                             movie_title  num_voted_users  \
# 0                                               Avatar            886204
# 1             Pirates of the Caribbean: At World's End            471220
# 2                                              Spectre            275868
# 3                                The Dark Knight Rises           1144337
# 4     Star Wars: Episode VII - The Force Awakens    ...                8
# ...                                                 ...              ...
# 5038                           Signed Sealed Delivered               629
# 5039                         The Following                         73839
# 5040                              A Plague So Pleasant                38
# 5041                                  Shanghai Calling              1255
# 5042                                 My Date with Drew              4285
#
#       num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                   3054.0  English  237000000.0      2009.0         7.9
# 1                   1238.0  English  300000000.0      2007.0         7.1
# 2                    994.0  English  245000000.0      2015.0         6.8
# 3                   2701.0  English  250000000.0      2012.0         8.5
# 4                      NaN      NaN          NaN         NaN         7.1
# ...                    ...      ...          ...         ...         ...
# 5038                   6.0  English          NaN      2013.0         7.7
# 5039                 359.0  English          NaN         NaN         7.5
# 5040                   3.0  English       1400.0      2013.0         6.3
# 5041                   9.0  English          NaN      2012.0         6.3
# 5042                  84.0  English       1100.0      2004.0         6.6
#
#       movie_facebook_likes
# 0                    33000
# 1                        0
# 2                    85000
# 3                   164000
# 4                        0
# ...                    ...
# 5038                    84
# 5039                 32000
# 5040                    16
# 5041                   660
# 5042                   456
#
# [5043 rows x 13 columns]

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
round((movies.isnull().sum()*100)/len(movies),2) > 5
# Out:
# director_name             False
# num_critic_for_reviews    False
# gross                      True
# genres                    False
# actor_1_name              False
# movie_title               False
# num_voted_users           False
# num_user_for_reviews      False
# language                  False
# budget                     True
# title_year                False
# imdb_score                False
# movie_facebook_likes      False
# dtype: bool

# %%
# Write your code for dropping the rows here
print(movies.shape)
movies = movies[~movies.gross.isnull()]
movies = movies[~movies.budget.isnull() ]
movies.head()
# Out:
# (5043, 13)
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 5     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 5                               John Carter            212204
#
#    num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                3054.0  English  237000000.0      2009.0         7.9
# 1                1238.0  English  300000000.0      2007.0         7.1
# 2                 994.0  English  245000000.0      2015.0         6.8
# 3                2701.0  English  250000000.0      2012.0         8.5
# 5                 738.0  English  263700000.0      2012.0         6.6
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 5                 24000

# %%
round((movies.isnull().sum()*100)/len(movies),2) > 5
# Out:
# director_name             False
# num_critic_for_reviews    False
# gross                     False
# genres                    False
# actor_1_name              False
# movie_title               False
# num_voted_users           False
# num_user_for_reviews      False
# language                  False
# budget                    False
# title_year                False
# imdb_score                False
# movie_facebook_likes      False
# dtype: bool

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
movies.isnull().sum(axis=0)
# Out:
# director_name             0
# num_critic_for_reviews    1
# gross                     0
# genres                    0
# actor_1_name              3
# movie_title               0
# num_voted_users           0
# num_user_for_reviews      0
# language                  3
# budget                    0
# title_year                0
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
movies['language'].value_counts()
# Out:
# English       3707
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Korean           5
# Portuguese       5
# Norwegian        4
# Thai             3
# Danish           3
# Dutch            3
# Persian          3
# Hebrew           3
# Aboriginal       2
# Dari             2
# Indonesian       2
# Maya             1
# Romanian         1
# Hungarian        1
# Dzongkha         1
# Filipino         1
# Bosnian          1
# Mongolian        1
# Russian          1
# Swedish          1
# Icelandic        1
# Kazakh           1
# None             1
# Arabic           1
# Telugu           1
# Zulu             1
# Vietnamese       1
# Czech            1
# Aramaic          1
# Name: language, dtype: int64

# %%
movies.loc[movies['language'].isnull(),'language'] = 'English'
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 5     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 5                               John Carter            212204
#
#    num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                3054.0  English  237000000.0      2009.0         7.9
# 1                1238.0  English  300000000.0      2007.0         7.1
# 2                 994.0  English  245000000.0      2015.0         6.8
# 3                2701.0  English  250000000.0      2012.0         8.5
# 5                 738.0  English  263700000.0      2012.0         6.6
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 5                 24000

# %%
############################
# English count increased by 3
movies['language'].value_counts()
# Out:
# English       3710
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Korean           5
# Portuguese       5
# Norwegian        4
# Thai             3
# Danish           3
# Dutch            3
# Persian          3
# Hebrew           3
# Aboriginal       2
# Dari             2
# Indonesian       2
# Maya             1
# Romanian         1
# Hungarian        1
# Dzongkha         1
# Filipino         1
# Bosnian          1
# Mongolian        1
# Russian          1
# Swedish          1
# Icelandic        1
# Kazakh           1
# None             1
# Arabic           1
# Telugu           1
# Zulu             1
# Vietnamese       1
# Czech            1
# Aramaic          1
# Name: language, dtype: int64

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
len(movies.index)/5043
# Out:
# 0.7715645449137418

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
movies[['budget','gross']].head()
# Out:
#         budget        gross
# 0  237000000.0  760505847.0
# 1  300000000.0  309404152.0
# 2  245000000.0  200074175.0
# 3  250000000.0  448130642.0
# 5  263700000.0   73058679.0

# %%
# Write your code for unit conversion here
movies['budget'] = movies['budget']/1000000
movies['gross'] = movies['gross']/1000000
movies[['budget','gross']].head()
# Out:
#    budget       gross
# 0   237.0  760.505847
# 1   300.0  309.404152
# 2   245.0  200.074175
# 3   250.0  448.130642
# 5   263.7   73.058679

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
movies['profit'] = movies['gross'] - movies['budget']
movies.head()
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1     Gore Verbinski                   302.0  309.404152
# 2         Sam Mendes                   602.0  200.074175
# 3  Christopher Nolan                   813.0  448.130642
# 5     Andrew Stanton                   462.0   73.058679
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 5                               John Carter            212204
#
#    num_user_for_reviews language  budget  title_year  imdb_score  \
# 0                3054.0  English   237.0      2009.0         7.9
# 1                1238.0  English   300.0      2007.0         7.1
# 2                 994.0  English   245.0      2015.0         6.8
# 3                2701.0  English   250.0      2012.0         8.5
# 5                 738.0  English   263.7      2012.0         6.6
#
#    movie_facebook_likes      profit
# 0                 33000  523.505847
# 1                     0    9.404152
# 2                 85000  -44.925825
# 3                164000  198.130642
# 5                 24000 -190.641321

# %%
# Write your code for sorting the dataframe here
movies = movies.sort_values(by=['profit'],ascending = False)
movies.head()
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 29     Colin Trevorrow                   644.0  652.177271
# 26       James Cameron                   315.0  658.672302
# 3024      George Lucas                   282.0  460.935665
# 3080  Steven Spielberg                   215.0  434.949459
#
#                                 genres         actor_1_name  \
# 0      Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29    Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                       Drama|Romance    Leonardo DiCaprio
# 3024   Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 3080                     Family|Sci-Fi         Henry Thomas
#
#                               movie_title  num_voted_users  \
# 0                                 Avatar            886204
# 29                        Jurassic World            418214
# 26                               Titanic            793059
# 3024  Star Wars: Episode IV - A New Hope            911097
# 3080          E.T. the Extra-Terrestrial            281842
#
#       num_user_for_reviews language  budget  title_year  imdb_score  \
# 0                   3054.0  English   237.0      2009.0         7.9
# 29                  1290.0  English   150.0      2015.0         7.0
# 26                  2528.0  English   200.0      1997.0         7.7
# 3024                1470.0  English    11.0      1977.0         8.7
# 3080                 515.0  English    10.5      1982.0         7.9
#
#       movie_facebook_likes      profit
# 0                    33000  523.505847
# 29                  150000  502.177271
# 26                   26000  458.672302
# 3024                 33000  449.935665
# 3080                 34000  424.449459

# %%
# Write code for profit vs budget plot here
import matplotlib.pyplot as plt
import seaborn as sns

movies.plot.scatter(x='budget', y='profit')

# %%
movies[movies['budget'] < 300].plot.scatter(x='budget', y='profit')

# %%
plt.figure(figsize=(10, 10))


plt.subplot(1, 2, 1)
sns.boxplot(y = 'profit', data=movies)
plt.title("profit")
plt.yscale('log')

plt.subplot(1, 2, 2)
sns.boxplot(y = 'budget', data=movies)
plt.title("budget")
plt.yscale('log')

plt.show()

# %%
# Write your code to get the top 10 profiting movies here
top10 = movies[['movie_title','profit']].sort_values(by=['profit'],ascending = False).head(10)
top10
# Out:
#                                      movie_title      profit
# 0                                        Avatar   523.505847
# 29                               Jurassic World   502.177271
# 26                                      Titanic   458.672302
# 3024         Star Wars: Episode IV - A New Hope   449.935665
# 3080                 E.T. the Extra-Terrestrial   424.449459
# 794                                The Avengers   403.279547
# 17                                 The Avengers   403.279547
# 509                               The Lion King   377.783777
# 240   Star Wars: Episode I - The Phantom Menace   359.544677
# 66                              The Dark Knight   348.316061

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
movies['movie_title'] = movies['movie_title'].str.replace('\xa0','')

# %%
# Write your code for dropping duplicate values here
movies.loc[movies['movie_title'] == 'The Avengers']
# Out:
#     director_name  num_critic_for_reviews       gross  \
# 794   Joss Whedon                   703.0  623.279547
# 17    Joss Whedon                   703.0  623.279547
#
#                       genres     actor_1_name   movie_title  num_voted_users  \
# 794  Action|Adventure|Sci-Fi  Chris Hemsworth  The Avengers           995415
# 17   Action|Adventure|Sci-Fi  Chris Hemsworth  The Avengers           995415
#
#      num_user_for_reviews language  budget  title_year  imdb_score  \
# 794                1722.0  English   220.0      2012.0         8.1
# 17                 1722.0  English   220.0      2012.0         8.1
#
#      movie_facebook_likes      profit
# 794                123000  403.279547
# 17                 123000  403.279547

# %%
movies = movies.drop_duplicates(keep='first',inplace=False)
movies.loc[movies['movie_title'] == 'The Avengers']
# Out:
#     director_name  num_critic_for_reviews       gross  \
# 794   Joss Whedon                   703.0  623.279547
#
#                       genres     actor_1_name   movie_title  num_voted_users  \
# 794  Action|Adventure|Sci-Fi  Chris Hemsworth  The Avengers           995415
#
#      num_user_for_reviews language  budget  title_year  imdb_score  \
# 794                1722.0  English   220.0      2012.0         8.1
#
#      movie_facebook_likes      profit
# 794                123000  403.279547

# %%
# Write code for repeating subtask 2 here
top10 = movies[['movie_title','director_name','profit']].sort_values(by=['profit'],ascending = False).head(10)
top10
# Out:
#                                     movie_title      director_name      profit
# 0                                        Avatar      James Cameron  523.505847
# 29                               Jurassic World    Colin Trevorrow  502.177271
# 26                                      Titanic      James Cameron  458.672302
# 3024         Star Wars: Episode IV - A New Hope       George Lucas  449.935665
# 3080                 E.T. the Extra-Terrestrial   Steven Spielberg  424.449459
# 794                                The Avengers        Joss Whedon  403.279547
# 509                               The Lion King       Roger Allers  377.783777
# 240   Star Wars: Episode I - The Phantom Menace       George Lucas  359.544677
# 66                              The Dark Knight  Christopher Nolan  348.316061
# 439                            The Hunger Games          Gary Ross  329.999255

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
IMDb_Top_250 = movies[movies['num_voted_users'] > 25000].sort_values(by=['imdb_score'],ascending = False)

# %%
IMDb_Top_250['Rank'] = IMDb_Top_250['imdb_score'].rank(ascending = False,numeric_only = True,method='first')
IMDb_Top_250 = IMDb_Top_250.head(250)

# %%
IMDb_Top_250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 339          Peter Jackson                   328.0  377.019252
# ...                    ...                     ...         ...
# 4640       Cristian Mungiu                   233.0    1.185783
# 2492        John Carpenter                   318.0   47.000000
# 4821        John Carpenter                   318.0   47.000000
# 639           Michael Mann                   209.0   28.965197
# 3029      David O. Russell                   410.0   93.571803
#
#                               genres      actor_1_name  \
# 1937                     Crime|Drama    Morgan Freeman
# 3466                     Crime|Drama         Al Pacino
# 2837                     Crime|Drama    Robert De Niro
# 66       Action|Crime|Drama|Thriller    Christian Bale
# 339   Action|Adventure|Drama|Fantasy     Orlando Bloom
# ...                              ...               ...
# 4640                           Drama  Anamaria Marinca
# 2492                 Horror|Thriller  Jamie Lee Curtis
# 4821                 Horror|Thriller  Jamie Lee Curtis
# 639         Biography|Drama|Thriller         Al Pacino
# 3029           Biography|Drama|Sport    Christian Bale
#
#                                         movie_title  num_voted_users  \
# 1937                       The Shawshank Redemption          1689764
# 3466                                  The Godfather          1155770
# 2837                         The Godfather: Part II           790926
# 66                                  The Dark Knight          1676169
# 339   The Lord of the Rings: The Return of the King          1215718
# ...                                             ...              ...
# 4640                   4 Months, 3 Weeks and 2 Days            44763
# 2492                                      Halloween           157857
# 4821                                      Halloween           157863
# 639                                     The Insider           133526
# 3029                                    The Fighter           275869
#
#       num_user_for_reviews  language  budget  title_year  imdb_score  \
# 1937                4144.0   English   25.00      1994.0         9.3
# 3466                2238.0   English    6.00      1972.0         9.2
# 2837                 650.0   English   13.00      1974.0         9.0
# 66                  4667.0   English  185.00      2008.0         9.0
# 339                 3189.0   English   94.00      2003.0         8.9
# ...                    ...       ...     ...         ...         ...
# 4640                 172.0  Romanian    0.59      2007.0         7.9
# 2492                1191.0   English    0.30      1978.0         7.9
# 4821                1191.0   English    0.30      1978.0         7.9
# 639                  521.0   English   68.00      1999.0         7.9
# 3029                 389.0   English   25.00      2010.0         7.9
#
#       movie_facebook_likes      profit   Rank
# 1937                108000    3.341469    1.0
# 3466                 43000  128.821952    2.0
# 2837                 14000   44.300000    3.0
# 66                   37000  348.316061    4.0
# 339                  16000  283.019252    5.0
# ...                    ...         ...    ...
# 4640                 14000    0.595783  246.0
# 2492                 12000   46.700000  247.0
# 4821                 12000   46.700000  248.0
# 639                      0  -39.034803  249.0
# 3029                 36000   68.571803  250.0
#
# [250 rows x 15 columns]

# %%
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250['language'] != 'English']
print(Top_Foreign_Lang_Film.shape)
Top_Foreign_Lang_Film.head()
# Out:
# (38, 15)
#            director_name  num_critic_for_reviews      gross  \
# 4498        Sergio Leone                   181.0   6.100000
# 4029  Fernando Meirelles                   214.0   7.563397
# 4747      Akira Kurosawa                   153.0   0.269061
# 2373      Hayao Miyazaki                   246.0  10.049886
# 4921        Majid Majidi                    46.0   0.925402
#
#                                   genres     actor_1_name  \
# 4498                             Western   Clint Eastwood
# 4029                         Crime|Drama      Alice Braga
# 4747              Action|Adventure|Drama  Takashi Shimura
# 2373  Adventure|Animation|Family|Fantasy   Bunta Sugawara
# 4921                        Drama|Family   Bahare Seddiqi
#
#                          movie_title  num_voted_users  num_user_for_reviews  \
# 4498  The Good, the Bad and the Ugly           503509                 780.0
# 4029                     City of God           533200                 749.0
# 4747                   Seven Samurai           229012                 596.0
# 2373                   Spirited Away           417971                 902.0
# 4921              Children of Heaven            27882                 130.0
#
#         language  budget  title_year  imdb_score  movie_facebook_likes  \
# 4498     Italian    1.20      1966.0         8.9                 20000
# 4029  Portuguese    3.30      2002.0         8.7                 28000
# 4747    Japanese    2.00      1954.0         8.7                 11000
# 2373    Japanese   19.00      2001.0         8.6                 28000
# 4921     Persian    0.18      1997.0         8.5                     0
#
#         profit  Rank
# 4498  4.900000   7.0
# 4029  4.263397  15.0
# 4747 -1.730939  17.0
# 2373 -8.950114  26.0
# 4921  0.745402  43.0

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here
top10director = movies
top10director['imdb_mean'] = top10director.groupby(['director_name'])['imdb_score'].transform('mean')
top10director['imdb_rank'] = top10director['imdb_mean'].rank(ascending = False,numeric_only = True,method='min')
top10director.sort_values(['imdb_rank','director_name'],ascending=[True, True], inplace=True)
top10director = top10director[top10director['imdb_rank'] < 11]
top10director.head()
# Out:
#          director_name  num_critic_for_reviews      gross  \
# 4427   Charles Chaplin                   120.0   0.163245
# 3175         Tony Kaye                   162.0   6.712241
# 2242  Alfred Hitchcock                   290.0  32.000000
# 4028   Damien Chazelle                   535.0  13.092000
# 4921      Majid Majidi                    46.0   0.925402
#
#                        genres      actor_1_name         movie_title  \
# 4427      Comedy|Drama|Family  Paulette Goddard        Modern Times
# 3175              Crime|Drama      Ethan Suplee  American History X
# 2242  Horror|Mystery|Thriller       Janet Leigh              Psycho
# 4028              Drama|Music      J.K. Simmons            Whiplash
# 4921             Drama|Family    Bahare Seddiqi  Children of Heaven
#
#       num_voted_users  num_user_for_reviews language    budget  title_year  \
# 4427           143086                 211.0  English  1.500000      1936.0
# 3175           782437                1420.0  English  7.500000      1998.0
# 2242           422432                1040.0  English  0.806947      1960.0
# 4028           399138                 731.0  English  3.300000      2014.0
# 4921            27882                 130.0  Persian  0.180000      1997.0
#
#       imdb_score  movie_facebook_likes     profit  imdb_mean  imdb_rank
# 4427         8.6                     0  -1.336755        8.6        1.0
# 3175         8.6                 35000  -0.787759        8.6        1.0
# 2242         8.5                 18000  31.193053        8.5        3.0
# 4028         8.5                129000   9.792000        8.5        3.0
# 4921         8.5                     0   0.745402        8.5        3.0

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
test1 = movies
test = movies['genres'].str.split('|',expand=True)
test = test[[0,1]]
test.columns = ['genre_1','genre_2']
test['genre_2'] = test['genre_2'].fillna(test['genre_1'])
test = pd.concat([test1,test],axis=1)
movies[['genre_1','genre_2']] = test[['genre_1','genre_2']]
movies.head()
# Out:
#          director_name  num_critic_for_reviews      gross  \
# 4427   Charles Chaplin                   120.0   0.163245
# 3175         Tony Kaye                   162.0   6.712241
# 2242  Alfred Hitchcock                   290.0  32.000000
# 4028   Damien Chazelle                   535.0  13.092000
# 4921      Majid Majidi                    46.0   0.925402
#
#                        genres      actor_1_name         movie_title  \
# 4427      Comedy|Drama|Family  Paulette Goddard        Modern Times
# 3175              Crime|Drama      Ethan Suplee  American History X
# 2242  Horror|Mystery|Thriller       Janet Leigh              Psycho
# 4028              Drama|Music      J.K. Simmons            Whiplash
# 4921             Drama|Family    Bahare Seddiqi  Children of Heaven
#
#       num_voted_users  num_user_for_reviews language    budget  title_year  \
# 4427           143086                 211.0  English  1.500000      1936.0
# 3175           782437                1420.0  English  7.500000      1998.0
# 2242           422432                1040.0  English  0.806947      1960.0
# 4028           399138                 731.0  English  3.300000      2014.0
# 4921            27882                 130.0  Persian  0.180000      1997.0
#
#       imdb_score  movie_facebook_likes     profit  imdb_mean  imdb_rank  \
# 4427         8.6                     0  -1.336755        8.6        1.0
# 3175         8.6                 35000  -0.787759        8.6        1.0
# 2242         8.5                 18000  31.193053        8.5        3.0
# 4028         8.5                129000   9.792000        8.5        3.0
# 4921         8.5                     0   0.745402        8.5        3.0
#
#      genre_1  genre_2
# 4427  Comedy    Drama
# 3175   Crime    Drama
# 2242  Horror  Mystery
# 4028   Drama    Music
# 4921   Drama   Family

# %%
# Write your code for grouping the dataframe here
movies_by_segment = movies.groupby(['genre_1','genre_2'])
movies_by_segment

# %%
# Write your code for getting the 5 most popular combo of genres here
PopGenre = movies_by_segment['gross'].mean().reset_index().nlargest(5,'gross')
PopGenre
#movies.loc[(movies['genre_1'] == 'Family') & (movies['genre_2'] == 'Sci-Fi')]
# Out:
#       genre_1    genre_2       gross
# 83     Family     Sci-Fi  434.949459
# 28  Adventure     Sci-Fi  228.627758
# 24  Adventure     Family  118.919540
# 18  Adventure  Animation  116.998550
# 1      Action  Adventure  109.595465

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
movies.shape
# Out:
# (3856, 18)

# %%
# Write your code for creating three new dataframes here

# Include all movies in which Meryl_Streep is the lead
Meryl_Streep = movies[movies['actor_1_name'] == 'Meryl Streep']
Meryl_Streep.head()
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 1925  Stephen Daldry                   174.0   41.597830
# 1106   Curtis Hanson                    42.0   46.815748
# 1483  Robert Redford                   227.0   14.998070
# 3135   Robert Altman                   211.0   20.338609
# 410     Nancy Meyers                   187.0  112.703470
#
#                                genres  actor_1_name               movie_title  \
# 1925                    Drama|Romance  Meryl Streep                 The Hours
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep            The River Wild
# 1483               Drama|Thriller|War  Meryl Streep           Lions for Lambs
# 3135               Comedy|Drama|Music  Meryl Streep  A Prairie Home Companion
# 410              Comedy|Drama|Romance  Meryl Streep          It's Complicated
#
#       num_voted_users  num_user_for_reviews language  budget  title_year  \
# 1925           102123                 660.0  English    25.0      2002.0
# 1106            32544                  69.0  English    45.0      1994.0
# 1483            41170                 298.0  English    35.0      2007.0
# 3135            19655                 280.0  English    10.0      2006.0
# 410             69860                 214.0  English    85.0      2009.0
#
#       imdb_score  movie_facebook_likes     profit  imdb_mean  imdb_rank  \
# 1925         7.6                     0  16.597830       7.45      419.0
# 1106         6.3                     0   1.815748       6.98     1115.0
# 1483         6.2                     0 -20.001930       6.84     1390.0
# 3135         6.8                   683  10.338609       6.80     1445.0
# 410          6.6                     0  27.703470       6.76     1589.0
#
#      genre_1    genre_2
# 1925   Drama    Romance
# 1106  Action  Adventure
# 1483   Drama   Thriller
# 3135  Comedy      Drama
# 410   Comedy      Drama

# %%
# Include all movies in which Leo_Caprio is the lead
Leo_Caprio = movies[movies['actor_1_name'] == 'Leonardo DiCaprio']
Leo_Caprio.head()
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 97       Christopher Nolan                   642.0  292.568851
# 296      Quentin Tarantino                   765.0  162.804648
# 26           James Cameron                   315.0  658.672302
# 179  Alejandro G. Iñárritu                   556.0  183.635922
# 452        Martin Scorsese                   490.0  127.968405
#
#                                genres       actor_1_name       movie_title  \
# 97   Action|Adventure|Sci-Fi|Thriller  Leonardo DiCaprio         Inception
# 296                     Drama|Western  Leonardo DiCaprio  Django Unchained
# 26                      Drama|Romance  Leonardo DiCaprio           Titanic
# 179  Adventure|Drama|Thriller|Western  Leonardo DiCaprio      The Revenant
# 452                  Mystery|Thriller  Leonardo DiCaprio    Shutter Island
#
#      num_voted_users  num_user_for_reviews language  budget  title_year  \
# 97           1468200                2803.0  English   160.0      2010.0
# 296           955174                1193.0  English   100.0      2012.0
# 26            793059                2528.0  English   200.0      1997.0
# 179           406020                1188.0  English   135.0      2015.0
# 452           786092                 964.0  English    80.0      2010.0
#
#      imdb_score  movie_facebook_likes      profit  imdb_mean  imdb_rank  \
# 97          8.8                175000  132.568851   8.425000       10.0
# 296         8.5                199000   62.804648   8.200000       33.0
# 26          7.7                 26000  458.672302   7.914286       75.0
# 179         8.1                190000   48.635922   7.840000      100.0
# 452         8.1                 53000   47.968405   7.675000      199.0
#
#        genre_1    genre_2
# 97      Action  Adventure
# 296      Drama    Western
# 26       Drama    Romance
# 179  Adventure      Drama
# 452    Mystery   Thriller

# %%
# Include all movies in which Brad_Pitt is the lead
Brad_Pitt = movies[movies['actor_1_name'] == 'Brad Pitt']
Brad_Pitt.head()
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 2204  Alejandro G. Iñárritu                   285.0   34.300771
# 101           David Fincher                   362.0  127.490802
# 683           David Fincher                   315.0   37.023395
# 611     Jean-Jacques Annaud                    76.0   37.901509
# 255              Doug Liman                   233.0  186.336103
#
#                                      genres actor_1_name  \
# 2204                                  Drama    Brad Pitt
# 101                   Drama|Fantasy|Romance    Brad Pitt
# 683                                   Drama    Brad Pitt
# 611   Adventure|Biography|Drama|History|War    Brad Pitt
# 255    Action|Comedy|Crime|Romance|Thriller    Brad Pitt
#
#                               movie_title  num_voted_users  \
# 2204                                Babel           243799
# 101   The Curious Case of Benjamin Button           459346
# 683                            Fight Club          1347461
# 611                  Seven Years in Tibet            96385
# 255                      Mr. & Mrs. Smith           348861
#
#       num_user_for_reviews language  budget  title_year  imdb_score  \
# 2204                 908.0  English    25.0      2006.0         7.5
# 101                  822.0  English   150.0      2008.0         7.8
# 683                 2968.0  English    63.0      1999.0         8.8
# 611                  119.0  English    70.0      1997.0         7.0
# 255                  798.0  English   120.0      2005.0         6.5
#
#       movie_facebook_likes     profit  imdb_mean  imdb_rank    genre_1  \
# 2204                     0   9.300771   7.840000      100.0      Drama
# 101                  23000 -22.509198   7.750000      132.0      Drama
# 683                  48000 -25.976605   7.750000      132.0      Drama
# 611                      0 -32.098491   7.233333      621.0  Adventure
# 255                      0  66.336103   7.128571      789.0     Action
#
#         genre_2
# 2204      Drama
# 101     Fantasy
# 683       Drama
# 611   Biography
# 255      Comedy

# %%
# Write your code for combining the three dataframes here
Combined = Meryl_Streep.append([Leo_Caprio,Brad_Pitt])
Combined
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 1925         Stephen Daldry                   174.0   41.597830
# 1106          Curtis Hanson                    42.0   46.815748
# 1483         Robert Redford                   227.0   14.998070
# 3135          Robert Altman                   211.0   20.338609
# 410            Nancy Meyers                   187.0  112.703470
# 1674          Carl Franklin                    64.0   23.209440
# 1408          David Frankel                   208.0  124.732962
# 1618          David Frankel                   234.0   63.536011
# 1575         Sydney Pollack                    66.0   87.100000
# 2781         Phyllida Lloyd                   331.0   29.959436
# 1204            Nora Ephron                   252.0   94.125426
# 97        Christopher Nolan                   642.0  292.568851
# 296       Quentin Tarantino                   765.0  162.804648
# 26            James Cameron                   315.0  658.672302
# 179   Alejandro G. Iñárritu                   556.0  183.635922
# 452         Martin Scorsese                   490.0  127.968405
# 361         Martin Scorsese                   352.0  132.373442
# 308         Martin Scorsese                   606.0  116.866727
# 257         Martin Scorsese                   267.0  102.608827
# 326         Martin Scorsese                   233.0   77.679638
# 911        Steven Spielberg                   194.0  164.435221
# 1114             Sam Mendes                   323.0   22.877808
# 990             Danny Boyle                   118.0   39.778599
# 307            Edward Zwick                   166.0   57.366262
# 1453         Clint Eastwood                   392.0   37.304950
# 50             Baz Luhrmann                   490.0  144.812796
# 3476           Baz Luhrmann                   490.0  144.812796
# 2757           Baz Luhrmann                   106.0   46.338728
# 641            Ridley Scott                   238.0   39.380442
# 1560              Sam Raimi                    63.0   18.636537
# 2067             Jerry Zaks                    45.0   12.782508
# 1422        Randall Wallace                    83.0   56.876365
# 2204  Alejandro G. Iñárritu                   285.0   34.300771
# 101           David Fincher                   362.0  127.490802
# 683           David Fincher                   315.0   37.023395
# 611     Jean-Jacques Annaud                    76.0   37.901509
# 255              Doug Liman                   233.0  186.336103
# 1490        Terrence Malick                   584.0   13.303319
# 2682         Andrew Dominik                   414.0   14.938570
# 1722         Andrew Dominik                   273.0    3.904982
# 2898             Tony Scott                   122.0   12.281500
# 382              Tony Scott                   142.0    0.026871
# 470              David Ayer                   406.0   85.707116
# 147       Wolfgang Petersen                   220.0  133.228348
# 940             Neil Jordan                   120.0  105.264608
# 400       Steven Soderbergh                   186.0  183.405771
# 254       Steven Soderbergh                   198.0  125.531634
# 792         Patrick Gilmore                    98.0   26.288320
# 2333    Angelina Jolie Pitt                   131.0    0.531009
#
#                                                  genres       actor_1_name  \
# 1925                                      Drama|Romance       Meryl Streep
# 1106                    Action|Adventure|Crime|Thriller       Meryl Streep
# 1483                                 Drama|Thriller|War       Meryl Streep
# 3135                                 Comedy|Drama|Music       Meryl Streep
# 410                                Comedy|Drama|Romance       Meryl Streep
# 1674                                              Drama       Meryl Streep
# 1408                               Comedy|Drama|Romance       Meryl Streep
# 1618                               Comedy|Drama|Romance       Meryl Streep
# 1575                            Biography|Drama|Romance       Meryl Streep
# 2781                            Biography|Drama|History       Meryl Streep
# 1204                            Biography|Drama|Romance       Meryl Streep
# 97                     Action|Adventure|Sci-Fi|Thriller  Leonardo DiCaprio
# 296                                       Drama|Western  Leonardo DiCaprio
# 26                                        Drama|Romance  Leonardo DiCaprio
# 179                    Adventure|Drama|Thriller|Western  Leonardo DiCaprio
# 452                                    Mystery|Thriller  Leonardo DiCaprio
# 361                                Crime|Drama|Thriller  Leonardo DiCaprio
# 308                        Biography|Comedy|Crime|Drama  Leonardo DiCaprio
# 257                                     Biography|Drama  Leonardo DiCaprio
# 326                                         Crime|Drama  Leonardo DiCaprio
# 911                               Biography|Crime|Drama  Leonardo DiCaprio
# 1114                                      Drama|Romance  Leonardo DiCaprio
# 990                            Adventure|Drama|Thriller  Leonardo DiCaprio
# 307                            Adventure|Drama|Thriller  Leonardo DiCaprio
# 1453                              Biography|Crime|Drama  Leonardo DiCaprio
# 50                                        Drama|Romance  Leonardo DiCaprio
# 3476                                      Drama|Romance  Leonardo DiCaprio
# 2757                                      Drama|Romance  Leonardo DiCaprio
# 641                               Action|Drama|Thriller  Leonardo DiCaprio
# 1560                            Action|Thriller|Western  Leonardo DiCaprio
# 2067                                              Drama  Leonardo DiCaprio
# 1422                                   Action|Adventure  Leonardo DiCaprio
# 2204                                              Drama          Brad Pitt
# 101                               Drama|Fantasy|Romance          Brad Pitt
# 683                                               Drama          Brad Pitt
# 611               Adventure|Biography|Drama|History|War          Brad Pitt
# 255                Action|Comedy|Crime|Romance|Thriller          Brad Pitt
# 1490                                      Drama|Fantasy          Brad Pitt
# 2682                                     Crime|Thriller          Brad Pitt
# 1722              Biography|Crime|Drama|History|Western          Brad Pitt
# 2898                Action|Crime|Drama|Romance|Thriller          Brad Pitt
# 382                               Action|Crime|Thriller          Brad Pitt
# 470                                    Action|Drama|War          Brad Pitt
# 147                                           Adventure          Brad Pitt
# 940                                Drama|Fantasy|Horror          Brad Pitt
# 400                                      Crime|Thriller          Brad Pitt
# 254                                      Crime|Thriller          Brad Pitt
# 792   Adventure|Animation|Comedy|Drama|Family|Fantas...          Brad Pitt
# 2333                                      Drama|Romance          Brad Pitt
#
#                                             movie_title  num_voted_users  \
# 1925                                          The Hours           102123
# 1106                                     The River Wild            32544
# 1483                                    Lions for Lambs            41170
# 3135                           A Prairie Home Companion            19655
# 410                                    It's Complicated            69860
# 1674                                     One True Thing             9283
# 1408                              The Devil Wears Prada           286178
# 1618                                       Hope Springs            34258
# 1575                                      Out of Africa            52339
# 2781                                      The Iron Lady            82327
# 1204                                      Julie & Julia            79264
# 97                                            Inception          1468200
# 296                                    Django Unchained           955174
# 26                                              Titanic           793059
# 179                                        The Revenant           406020
# 452                                      Shutter Island           786092
# 361                                        The Departed           873649
# 308                             The Wolf of Wall Street           780588
# 257                                         The Aviator           264318
# 326                                   Gangs of New York           314033
# 911                                 Catch Me If You Can           525801
# 1114                                 Revolutionary Road           152591
# 990                                           The Beach           176169
# 307                                       Blood Diamond           400292
# 1453                                           J. Edgar           102728
# 50                                     The Great Gatsby           362912
# 3476                                   The Great Gatsby           362933
# 2757                                     Romeo + Juliet           167750
# 641                                        Body of Lies           174248
# 1560                             The Quick and the Dead            69197
# 2067                                      Marvin's Room            20163
# 1422                           The Man in the Iron Mask           125219
# 2204                                              Babel           243799
# 101                 The Curious Case of Benjamin Button           459346
# 683                                          Fight Club          1347461
# 611                                Seven Years in Tibet            96385
# 255                                    Mr. & Mrs. Smith           348861
# 1490                                   The Tree of Life           136367
# 2682                                Killing Them Softly           111625
# 1722  The Assassination of Jesse James by the Coward...           136104
# 2898                                       True Romance           163492
# 382                                            Spy Game           121259
# 470                                                Fury           303185
# 147                                                Troy           381672
# 940   Interview with the Vampire: The Vampire Chroni...           239752
# 400                                      Ocean's Eleven           402645
# 254                                      Ocean's Twelve           284852
# 792                    Sinbad: Legend of the Seven Seas            36144
# 2333                                         By the Sea             7976
#
#       num_user_for_reviews language  budget  title_year  imdb_score  \
# 1925                 660.0  English    25.0      2002.0         7.6
# 1106                  69.0  English    45.0      1994.0         6.3
# 1483                 298.0  English    35.0      2007.0         6.2
# 3135                 280.0  English    10.0      2006.0         6.8
# 410                  214.0  English    85.0      2009.0         6.6
# 1674                 112.0  English    30.0      1998.0         7.0
# 1408                 631.0  English    35.0      2006.0         6.8
# 1618                 178.0  English    30.0      2012.0         6.3
# 1575                 200.0  English    31.0      1985.0         7.2
# 2781                 350.0  English    13.0      2011.0         6.4
# 1204                 277.0  English    40.0      2009.0         7.0
# 97                  2803.0  English   160.0      2010.0         8.8
# 296                 1193.0  English   100.0      2012.0         8.5
# 26                  2528.0  English   200.0      1997.0         7.7
# 179                 1188.0  English   135.0      2015.0         8.1
# 452                  964.0  English    80.0      2010.0         8.1
# 361                 2054.0  English    90.0      2006.0         8.5
# 308                 1138.0  English   100.0      2013.0         8.2
# 257                  799.0  English   110.0      2004.0         7.5
# 326                 1166.0  English   100.0      2002.0         7.5
# 911                  667.0  English    52.0      2002.0         8.0
# 1114                 414.0  English    35.0      2008.0         7.3
# 990                  548.0  English    50.0      2000.0         6.6
# 307                  657.0  English   100.0      2006.0         8.0
# 1453                 279.0  English    35.0      2011.0         6.6
# 50                   753.0  English   105.0      2013.0         7.3
# 3476                 753.0  English   105.0      2013.0         7.3
# 2757                 506.0  English    14.5      1996.0         6.8
# 641                  263.0  English    70.0      2008.0         7.1
# 1560                 216.0  English    32.0      1995.0         6.4
# 2067                  71.0  English    23.0      1996.0         6.7
# 1422                 244.0  English    35.0      1998.0         6.4
# 2204                 908.0  English    25.0      2006.0         7.5
# 101                  822.0  English   150.0      2008.0         7.8
# 683                 2968.0  English    63.0      1999.0         8.8
# 611                  119.0  English    70.0      1997.0         7.0
# 255                  798.0  English   120.0      2005.0         6.5
# 1490                 975.0  English    32.0      2011.0         6.7
# 2682                 369.0  English    15.0      2012.0         6.2
# 1722                 415.0  English    30.0      2007.0         7.5
# 2898                 460.0  English    13.0      1993.0         8.0
# 382                  361.0  English    92.0      2001.0         7.0
# 470                  701.0  English    68.0      2014.0         7.6
# 147                 1694.0  English   175.0      2004.0         7.2
# 940                  406.0  English    60.0      1994.0         7.6
# 400                  845.0  English    85.0      2001.0         7.8
# 254                  627.0  English   110.0      2004.0         6.4
# 792                   91.0  English    60.0      2003.0         6.7
# 2333                  61.0  English    10.0      2015.0         5.3
#
#       movie_facebook_likes      profit  imdb_mean  imdb_rank    genre_1  \
# 1925                     0   16.597830   7.450000      419.0      Drama
# 1106                     0    1.815748   6.980000     1115.0     Action
# 1483                     0  -20.001930   6.840000     1390.0      Drama
# 3135                   683   10.338609   6.800000     1445.0     Comedy
# 410                      0   27.703470   6.760000     1589.0     Comedy
# 1674                   592   -6.790560   6.600000     1851.0      Drama
# 1408                     0   89.732962   6.600000     1857.0     Comedy
# 1618                     0   33.536011   6.600000     1857.0     Comedy
# 1575                     0   56.100000   6.580000     1947.0  Biography
# 2781                 18000   16.959436   6.350000     2359.0  Biography
# 1204                 13000   54.125426   6.166667     2609.0  Biography
# 97                  175000  132.568851   8.425000       10.0     Action
# 296                 199000   62.804648   8.200000       33.0      Drama
# 26                   26000  458.672302   7.914286       75.0      Drama
# 179                 190000   48.635922   7.840000      100.0  Adventure
# 452                  53000   47.968405   7.675000      199.0    Mystery
# 361                  29000   42.373442   7.675000      199.0      Crime
# 308                 138000   16.866727   7.675000      199.0  Biography
# 257                      0   -7.391173   7.675000      199.0  Biography
# 326                      0  -22.320362   7.675000      199.0      Crime
# 911                  15000  112.435221   7.544000      324.0  Biography
# 1114                     0  -12.122192   7.500000      398.0      Drama
# 990                      0  -10.221401   7.437500      429.0  Adventure
# 307                  14000  -42.633738   7.325000      520.0  Adventure
# 1453                 16000    2.304950   7.205263      634.0  Biography
# 50                  115000   39.812796   7.120000      810.0      Drama
# 3476                115000   39.812796   7.120000      810.0      Drama
# 2757                 10000   31.838728   7.120000      810.0      Drama
# 641                      0  -30.619558   7.070588      916.0     Action
# 1560                     0  -13.363463   6.850000     1337.0     Action
# 2067                  1000  -10.217492   6.700000     1676.0      Drama
# 1422                     0   21.876365   6.625000     1837.0     Action
# 2204                     0    9.300771   7.840000      100.0      Drama
# 101                  23000  -22.509198   7.750000      132.0      Drama
# 683                  48000  -25.976605   7.750000      132.0      Drama
# 611                      0  -32.098491   7.233333      621.0  Adventure
# 255                      0   66.336103   7.128571      789.0     Action
# 1490                 39000  -18.696681   7.000000      980.0      Drama
# 2682                 20000   -0.061430   6.850000     1353.0      Crime
# 1722                     0  -26.095018   6.850000     1353.0  Biography
# 2898                 15000   -0.718500   6.791667     1501.0     Action
# 382                      0  -91.973129   6.791667     1501.0     Action
# 470                  82000   17.707116   6.771429     1538.0     Action
# 147                      0  -41.771652   6.766667     1561.0  Adventure
# 940                  11000   45.264608   6.762500     1576.0      Drama
# 400                      0   98.405771   6.706250     1660.0      Crime
# 254                      0   15.531634   6.706250     1660.0      Crime
# 792                    880  -33.711680   6.700000     1676.0  Adventure
# 2333                     0   -9.468991   5.600000     3275.0      Drama
#
#         genre_2
# 1925    Romance
# 1106  Adventure
# 1483   Thriller
# 3135      Drama
# 410       Drama
# 1674      Drama
# 1408      Drama
# 1618      Drama
# 1575      Drama
# 2781      Drama
# 1204      Drama
# 97    Adventure
# 296     Western
# 26      Romance
# 179       Drama
# 452    Thriller
# 361       Drama
# 308      Comedy
# 257       Drama
# 326       Drama
# 911       Crime
# 1114    Romance
# 990       Drama
# 307       Drama
# 1453      Crime
# 50      Romance
# 3476    Romance
# 2757    Romance
# 641       Drama
# 1560   Thriller
# 2067      Drama
# 1422  Adventure
# 2204      Drama
# 101     Fantasy
# 683       Drama
# 611   Biography
# 255      Comedy
# 1490    Fantasy
# 2682   Thriller
# 1722      Crime
# 2898      Crime
# 382       Crime
# 470       Drama
# 147   Adventure
# 940     Fantasy
# 400    Thriller
# 254    Thriller
# 792   Animation
# 2333    Romance

# %%
# Write your code for grouping the combined dataframe here
Combined1 = Combined.groupby(['actor_1_name'])

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
Combined1['num_critic_for_reviews','num_user_for_reviews'].mean().sort_values(by = ['num_critic_for_reviews','num_user_for_reviews'],ascending = False)
# Out:
#                    num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Leonardo DiCaprio              330.190476            914.476190
# Brad Pitt                      245.000000            742.352941
# Meryl Streep                   181.454545            297.181818

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
movies.head()
# Out:
#          director_name  num_critic_for_reviews      gross  \
# 4427   Charles Chaplin                   120.0   0.163245
# 3175         Tony Kaye                   162.0   6.712241
# 2242  Alfred Hitchcock                   290.0  32.000000
# 4028   Damien Chazelle                   535.0  13.092000
# 4921      Majid Majidi                    46.0   0.925402
#
#                        genres      actor_1_name         movie_title  \
# 4427      Comedy|Drama|Family  Paulette Goddard        Modern Times
# 3175              Crime|Drama      Ethan Suplee  American History X
# 2242  Horror|Mystery|Thriller       Janet Leigh              Psycho
# 4028              Drama|Music      J.K. Simmons            Whiplash
# 4921             Drama|Family    Bahare Seddiqi  Children of Heaven
#
#       num_voted_users  num_user_for_reviews language    budget  title_year  \
# 4427           143086                 211.0  English  1.500000      1936.0
# 3175           782437                1420.0  English  7.500000      1998.0
# 2242           422432                1040.0  English  0.806947      1960.0
# 4028           399138                 731.0  English  3.300000      2014.0
# 4921            27882                 130.0  Persian  0.180000      1997.0
#
#       imdb_score  movie_facebook_likes     profit  imdb_mean  imdb_rank  \
# 4427         8.6                     0  -1.336755        8.6        1.0
# 3175         8.6                 35000  -0.787759        8.6        1.0
# 2242         8.5                 18000  31.193053        8.5        3.0
# 4028         8.5                129000   9.792000        8.5        3.0
# 4921         8.5                     0   0.745402        8.5        3.0
#
#      genre_1  genre_2
# 4427  Comedy    Drama
# 3175   Crime    Drama
# 2242  Horror  Mystery
# 4028   Drama    Music
# 4921   Drama   Family

# %%
# Write the code for calculating decade here
movies['decade'] = movies['title_year'].apply(lambda x : str(int((x//10)*10)) + 's')
movies = movies.sort_values(by = ['decade'])
movies.head()
# Out:
#           director_name  num_critic_for_reviews      gross  \
# 4958  Harry F. Millarde                     1.0   3.000000
# 2734         Fritz Lang                   260.0   0.026435
# 4812     Harry Beaumont                    36.0   2.808000
# 4427    Charles Chaplin                   120.0   0.163245
# 4157     Victor Fleming                   213.0  22.202612
#
#                                 genres       actor_1_name  \
# 4958                       Crime|Drama       Stephen Carr
# 2734                      Drama|Sci-Fi      Brigitte Helm
# 4812                   Musical|Romance         Anita Page
# 4427               Comedy|Drama|Family   Paulette Goddard
# 4157  Adventure|Family|Fantasy|Musical  Margaret Hamilton
#
#                          movie_title  num_voted_users  num_user_for_reviews  \
# 4958  Over the Hill to the Poorhouse                5                   1.0
# 2734                      Metropolis           111841                 413.0
# 4812             The Broadway Melody             4546                  71.0
# 4427                    Modern Times           143086                 211.0
# 4157                The Wizard of Oz           291875                 533.0
#
#      language  budget  title_year  imdb_score  movie_facebook_likes  \
# 4958  English   0.100      1920.0         4.8                     0
# 2734   German   6.000      1927.0         8.3                 12000
# 4812  English   0.379      1929.0         6.3                   167
# 4427  English   1.500      1936.0         8.6                     0
# 4157  English   2.800      1939.0         8.1                 14000
#
#          profit  imdb_mean  imdb_rank    genre_1  genre_2 decade
# 4958   2.900000       4.80     3684.0      Crime    Drama  1920s
# 2734  -5.973565       8.30       22.0      Drama   Sci-Fi  1920s
# 4812   2.429000       6.30     2416.0    Musical  Romance  1920s
# 4427  -1.336755       8.60        1.0     Comedy    Drama  1930s
# 4157  19.402612       8.15       46.0  Adventure   Family  1930s

# %%
# Write your code for creating the data frame df_by_decade here 
df_by_decade = movies.groupby(['decade'])['num_voted_users'].sum()
df_by_decade
# Out:
# decade
# 1920s       116392
# 1930s       804839
# 1940s       230838
# 1950s       678336
# 1960s      2983442
# 1970s      8524102
# 1980s     19987476
# 1990s     69735679
# 2000s    170908676
# 2010s    120640994
# Name: num_voted_users, dtype: int64

# %%
# Write your code for plotting number of voted users vs decade
plt.figure(figsize=(20, 10))


plt.subplot(1, 2, 1)
plt.plot(df_by_decade)
plt.title('plotting number of voted users vs decade')
plt.xlabel('decades')
plt.ylabel('no of votes')

df_by_decade = pd.DataFrame(df_by_decade)
df_by_decade =  df_by_decade.reset_index()

plt.subplot(1, 2, 2)
plt.bar(df_by_decade['decade'],df_by_decade['num_voted_users'], align='center', alpha=0.5)
plt.ylabel('no of votes')
plt.xlabel('decades')
plt.title('plotting number of voted users vs decade')
# Out:
# Text(0.5, 1.0, 'plotting number of voted users vs decade')
